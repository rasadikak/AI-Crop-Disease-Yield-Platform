# %%
import sys
# !{sys.executable} -m pip install numpy pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
world_df= pd.read_csv("yield_df.csv")
sl_df= world_df[world_df["Area"]=="Sri Lanka"]
print(sl_df.shape)
print(sl_df.columns)
# Out:
# (184, 8)
# Index(['Unnamed: 0', 'Area', 'Item', 'Year', 'hg/ha_yield',
#        'average_rain_fall_mm_per_year', 'pesticides_tonnes', 'avg_temp'],
#       dtype='object')

# %%
sl_df["kg/ha_yeild"]= sl_df["hg/ha_yield"]/10

print(sl_df.columns)
# Out:
# Index(['Unnamed: 0', 'Area', 'Item', 'Year', 'hg/ha_yield',
#        'average_rain_fall_mm_per_year', 'pesticides_tonnes', 'avg_temp',
#        'kg/ha_yeild'],
#       dtype='object')
# C:\Users\User\AppData\Local\Temp\ipykernel_21384\3206741270.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sl_df["kg/ha_yeild"]= sl_df["hg/ha_yield"]/10

# %%
print(sl_df["Item"].unique())
print(sl_df["Year"].min(), sl_df["Year"].max())
print(sl_df.head(10))
# Out:
# ['Cassava' 'Maize' 'Plantains and others' 'Potatoes' 'Rice, paddy'
#  'Sorghum' 'Soybeans' 'Sweet potatoes']
# 1990 2013
#        Unnamed: 0       Area                  Item  Year  hg/ha_yield  \
# 25682       25682  Sri Lanka               Cassava  1990        87717
# 25683       25683  Sri Lanka                 Maize  1990        11227
# 25684       25684  Sri Lanka  Plantains and others  1990       140381
# 25685       25685  Sri Lanka              Potatoes  1990       110520
# 25686       25686  Sri Lanka           Rice, paddy  1990        30643
# 25687       25687  Sri Lanka               Sorghum  1990         7143
# 25688       25688  Sri Lanka              Soybeans  1990         8040
# 25689       25689  Sri Lanka        Sweet potatoes  1990        64750
# 25690       25690  Sri Lanka               Cassava  1991        92373
# 25691       25691  Sri Lanka                 Maize  1991        11916
#
# ...

# %%
sl_df= sl_df.drop(columns=["hg/ha_yield"])
